# %% [markdown]
# SINCHANA AB AMB2248

# %%
import pandas as pd
data={
    "farm":["farm a","farm b","farmc","farm d"],
    "crop":["wheat","rice","wheat","maize"],
    "area_hecates":[10,15,8,21],
    "production_tons":[23,4,67,78]
}
df=pd.DataFrame(data)
print(df)
# Out:
#      farm   crop  area_hecates  production_tons
# 0  farm a  wheat            10               23
# 1  farm b   rice            15                4
# 2   farmc  wheat             8               67
# 3  farm d  maize            21               78

# %%
# add new column
# yield=production/area
df["yield_ton_per_hectare"]=df["production_tons"]/["area_hectares"]
print(df)
# Out:
#      farm   crop  area_hecates  production_tons  yield_ton_per_hectare
# 0  farm a  wheat            10               23               2.300000
# 1  farm b   rice            15                4               0.266667
# 2   farmc  wheat             8               67               8.375000
# 3  farm d  maize            21               78               3.714286

# %%
# Out:
# crop
# maize     3.714286
# rice      0.266667
# wheat    10.675000
# Name: yield_ton_per_hectare, dtype: float64
