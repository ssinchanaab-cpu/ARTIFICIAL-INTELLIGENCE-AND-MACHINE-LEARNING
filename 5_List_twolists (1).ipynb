# %% [markdown]
# SINCHANA AB AMB2248

# %% [markdown]
# Example 1: Crop Names and Their Water Requirement

# %%
crops = ["Rice", "Wheat", "Millet", "Maize", "Pulses"]
water_need = [300, 200, 100, 150, 80]   # in mm

print("length",len(crops))
print("range",range(len(crops)))

print("Crop and water requirement:")
for i in range(len(crops)):
    print(crops[i], "-", water_need[i], "mm")
# Out:
# length 5
# range range(0, 5)
# Crop and water requirement:
# Rice - 300 mm
# Wheat - 200 mm
# Millet - 100 mm
# Maize - 150 mm
# Pulses - 80 mm

# %%
crops = ["Rice", "Wheat", "Millet", "Maize", "Pulses"]
water_need = [300, 200, 100, 150, 80]

print("Crop and water requirement:")
for crop, water in zip(crops, water_need):
    print(crop, "-", water, "mm")
# Out:
# Crop and water requirement:
# Rice - 300 mm
# Wheat - 200 mm
# Millet - 100 mm
# Maize - 150 mm
# Pulses - 80 mm

# %% [markdown]
# Example 2: Identify Crops Needing High Water

# %%
crops = ["Rice", "Wheat", "Millet", "Maize", "Pulses"]
water_need = [300, 200, 100, 150, 80]

print("Crops needing high water (>180 mm):")
for i in range(len(water_need)):
    if water_need[i] > 180:
        print(crops[i])
# Out:
# Crops needing high water (>180 mm):
# Rice
# Wheat

# %%
crops = ["Rice", "Wheat", "Millet", "Maize", "Pulses"]
water_need = [300, 200, 100, 150, 80]

print("Crops needing high water (>180 mm):")
for crop, water in zip(crops, water_need):
    if water > 180:
        print(crop)
# Out:
# Crops needing high water (>180 mm):
# Rice
# Wheat

# %% [markdown]
# Example 3: Find the Crop with Maximum Water Requirement

# %%
crops = ["Rice", "Wheat", "Millet", "Maize", "Pulses"]
water_need = [300, 200, 100, 150, 80]

max_water = max(water_need)
index = water_need.index(max_water)
print("Crop with highest water requirement:", crops[index])

max_crop = max(zip(water_need, crops))
print(max_crop)
print("Crop with highest water requirement:", max_crop[1])
# Out:
# Crop with highest water requirement: Rice
# (300, 'Rice')
# Crop with highest water requirement: Rice

# %% [markdown]
# Example 4: Replace a Crop in the List

# %%
crops = ["Rice", "Wheat", "Millet", "Maize"]
crops[2] = "Pulses"

print("Updated crop list:", crops)
# Out:
# Updated crop list: ['Rice', 'Wheat', 'Pulses', 'Maize']

# %% [markdown]
#  Example 4: Find Average Yield of Crops

# %%
crops = ["Rice", "Wheat", "Maize", "Pulses"]
yield_tons = [3.5, 4.0, 2.8, 1.5]   # tons per hectare

average_yield = sum(yield_tons) / len(yield_tons)
print("Average crop yield:", average_yield, "tons/hectare")
# Out:
# Average crop yield: 2.95 tons/hectare

# %% [markdown]
# Example 5: Display maximum yield crop

# %%
max_yield = max(yield_tons)
index = yield_tons.index(max_yield)

print("Crop with highest yield:", crops[index])
# Out:
# Crop with highest yield: Wheat

# %% [markdown]
# Example 6: Crops with Yield Above Average

# %%
average_yield = sum(yield_tons) / len(yield_tons)

print("High yield crops:")
for i in range(len(crops)):
    if yield_tons[i] > average_yield:
        print(crops[i])
# Out:
# High yield crops:
# Rice
# Wheat

# %% [markdown]
# Example 7: Increase Yield by 15% (Improved Seeds)

# %%
updated_yield = []
for y in yield_tons:
    updated_yield.append(y * 1.15)

print("Actual yields:", yield_tons)
print("Updated yields:", updated_yield)
# Out:
# Actual yields: [3.5, 4.0, 2.8, 1.5]
# Updated yields: [4.0249999999999995, 4.6, 3.2199999999999998, 1.7249999999999999]

# %% [markdown]
# Example 8: Fertilizer Recommendation Using Two Lists

# %%
crops = ["Rice", "Wheat", "Maize", "Pulses"]
fertilizer = ["Urea", "DAP", "NPK", "Compost"]

print("Recommended fertilizer:")
for i in range(len(crops)):
    print(crops[i], "→", fertilizer[i])

print("Recommended fertilizer:")
for crop, fert in zip(crops, fertilizer):
    print(crop, "→", fert)
# Out:
# Recommended fertilizer:
# Rice → Urea
# Wheat → DAP
# Maize → NPK
# Pulses → Compost
# Recommended fertilizer:
# Rice → Urea
# Wheat → DAP
# Maize → NPK
# Pulses → Compost

# %% [markdown]
# Example 5: Check Which Crops Need Irrigation

# %%
crops = ["Rice", "Wheat", "Millet", "Maize"]
soil_moisture = [25, 45, 60, 30]   # %

print("Crops needing irrigation:")
for i in range(len(crops)):
    if soil_moisture[i] < 40:
        print(crops[i])
# Out:
# Crops needing irrigation:
# Rice
# Maize

# %%
#Farm Equipment Cost
equipment = ["Tractor", "Plough", "Harvester", "Seeder", "Sprayer", "Thresher"]
cost = [850000, 25000.15, 1200000, 60000, 18000, 95000]

# %%
#List all equipment costing more than the average cost.
average_cost = sum(cost) / len(cost)
print("Average cost:", average_cost)

equ_above_average = []
print("Equipment costing more than average:", equ_above_average)
# Out:
# Average cost: 374666.69166666665
# Equipment costing more than average: []

# %%
# Display equipment whose cost is greater than the average cost (if any).
average_cost = sum(cost) / len(cost)
count=0
print("Average cost:", average_cost)
for i in range(len(cost)):
    if cost[i]> average_cost:   #850000 T    25000 F  12lk  T
        count=count+1           #count =1    count=1   count=2
print(count)

#  OR
count1=0
for e,c in zip(equipment, cost):
    if c > average_cost:
          count1=count1+1
print(count)
# Out:
# Average cost: 374666.69166666665
# 2
# 2

# %%
#Increase cost by 8%

updated_cost = []
for y in cost:
    updated_cost.append(round((y * 1.08),2))

print("Actual costs:", cost)
print("Updated costs:", updated_cost)

updated_cost = [int(c * 1.08) for c in cost]
print(" Updated costs after 8% increase:", updated_cost)
# Out:
# Actual costs: [850000, 25000.15, 1200000, 60000, 18000, 95000]
# Updated costs: [918000.0, 27000.16, 1296000.0, 64800.0, 19440.0, 102600.0]
#  Updated costs after 8% increase: [918000, 27000, 1296000, 64800, 19440, 102600]

# %%
#  Replace equipment with cost above ₹10,00,000 as "High Investment"

equipment_updated = []

for i in range(len(equipment)):
    if updated_cost[i] > 1000000:
        equipment_updated.append("High Investment")
    else:
        equipment_updated.append(equipment[i])

print(" Equipment list after replacement:\n", equipment_updated)

equipment_updated1 = [
    "High Investment" if c > 1000000 else e
    for e, c in zip(equipment, updated_cost)
]
print("Equipment updated with 'High Investment' :\n", equipment_updated1)
# Out:
#  Equipment list after replacement:
#  ['Tractor', 'Plough', 'High Investment', 'Seeder', 'Sprayer', 'Thresher']
# Equipment updated with 'High Investment' :
#  ['Tractor', 'Plough', 'High Investment', 'Seeder', 'Sprayer', 'Thresher']

# %%
# 7.	Count the number of equipment items costing less than ₹50,000.

equipment = ["Tractor", "Plough", "Harvester", "Seeder", "Sprayer", "Thresher"]
cost = [850000, 25000, 1200000, 60000, 18000, 95000]

count = 0

for c in cost:
    if c < 50000:
        count += 1

print("Number of equipment items costing less than ₹50,000:", count)
# Out:
# Number of equipment items costing less than ₹50,000: 2

# %%
# 8. Display equipment eligible for government subsidy (cost ≤ ₹1,00,000)

print("Equipment eligible for government subsidy:")

for i in range(len(equipment)):
    if cost[i] <= 100000:
        print(equipment[i])
# Out:
# Equipment eligible for government subsidy:
# Plough
# Seeder
# Sprayer
# Thresher

# %%
# 11. Sort the equipment based on their cost in ascending order

equipment = ["Tractor", "Plough", "Harvester", "Seeder", "Sprayer", "Thresher"]
cost = [850000, 25000, 1200000, 60000, 18000, 95000]

# Combine equipment and cost
items = []

for i in range(len(equipment)):
    items.append([cost[i], equipment[i]])

print(items)
# Sort by cost (ascending)
#python compares from left to right, since cost is the first element, it sorts by cost
items.sort()
print(items)

print("\nEquipment sorted by cost (ascending):")
for item in items:
    print(item[1], "-", item[0])
# Out:
# [[850000, 'Tractor'], [25000, 'Plough'], [1200000, 'Harvester'], [60000, 'Seeder'], [18000, 'Sprayer'], [95000, 'Thresher']]
# [[18000, 'Sprayer'], [25000, 'Plough'], [60000, 'Seeder'], [95000, 'Thresher'], [850000, 'Tractor'], [1200000, 'Harvester']]
#
# Equipment sorted by cost (ascending):
# Sprayer - 18000
# Plough - 25000
# Seeder - 60000
# Thresher - 95000
# Tractor - 850000
# Harvester - 1200000

# %%
# 16. Identify equipment costing more than twice the minimum cost
min_cost = min(updated_cost)
expensive_equipment = []

for i in range(len(equipment)):
    if updated_cost[i] > 2 * min_cost:
        expensive_equipment.append(equipment[i])

print("Equipment costing more than twice the minimum cost:", expensive_equipment)



min_cost = min(updated_cost)
expensive_equipment = [
    e for e, c in zip(equipment, updated_cost) if c > 2 * min_cost
]
print("Equipment costing more than twice the minimum cost:", expensive_equipment)
# Out:
# Equipment costing more than twice the minimum cost: ['Tractor', 'Harvester', 'Seeder', 'Thresher']
# Equipment costing more than twice the minimum cost: ['Tractor', 'Harvester', 'Seeder', 'Thresher']

# %%
# 17. Check whether all costs are below ₹15,00,000
all_below_limit = True

for c in updated_cost:
    if c >= 1500000:
        all_below_limit = False
        break

print(" All costs below ₹15,00,000:", all_below_limit)

all_below_limit = all(c < 1500000 for c in updated_cost)
print("All costs below ₹15,00,000:", all_below_limit)
# Out:
#  All costs below ₹15,00,000: True
# All costs below ₹15,00,000: True

# %%
# 18. Top three most expensive equipment
# Combine equipment and cost

equipment = ["Tractor", "Plough", "Harvester", "Seeder", "Sprayer", "Thresher"]
cost = [850000, 25000, 1200000, 60000, 18000, 95000]

# Step 1: Copy and sort cost list in descending order
sorted_cost = cost.copy()
sorted_cost.sort(reverse=True)

# Step 2: Take top three costs
top_three_costs = sorted_cost[:3]

# Step 3: Find corresponding equipment
top_three = []

for c in top_three_costs:
    index = cost.index(c)
    top_three.append((equipment[index], c))

print("Top three most expensive equipment:", top_three)
# Out:
# Top three most expensive equipment: [('Harvester', 1200000), ('Tractor', 850000), ('Thresher', 95000)]

# %%
# 18. Top three most expensive equipment

equipment = ["Tractor", "Plough", "Harvester", "Seeder", "Sprayer", "Thresher"]
cost = [850000, 25000.15, 1200000, 60000, 18000, 95000]

# Combine cost and equipment (cost first)
items = []

for i in range(len(equipment)):
    items.append([cost[i], equipment[i]])

# Sort in descending order by cost
items.sort(reverse=True)

# Take top three
top_three = items[:3]

print("Top three most expensive equipment:")
for item in top_three:
    print(item[1], "-", item[0])

# %%
# 19. Reduce cost by 15% for subsidy-eligible equipment
# (Assuming subsidy for equipment costing below ₹1,00,000)
subsidy_cost = []
for c in cost:
    if c < 100000:
        subsidy_cost.append(int(c * 0.85))
    else:
        subsidy_cost.append(c)
print("Costs after subsidy:", subsidy_cost)

subsidy_cost = [
    int(c * 0.85) if c < 100000 else c
    for c in cost
]
print("Costs after subsidy:", subsidy_cost)
# Out:
# Costs after subsidy: [850000, 21250, 1200000, 51000, 15300, 80750]
# Costs after subsidy: [850000, 21250, 1200000, 51000, 15300, 80750]

# %%
# 20. Create cost category list
categories = []
for c in updated_cost:
    if c < 100000:
        categories.append("Low")
    elif c <= 500000:
        categories.append("Medium")
    else:
        categories.append("High")

print(" Cost categories:", categories)
# Out:
#  Cost categories: ['High', 'Low', 'High', 'Low', 'Low', 'Medium']

# %%
print(bool("Hello"))
print(bool(15))
print(True)
print("TRUE")   #string
print("True")
print("good")
# Out:
# True
# True
# True
# TRUE
# True
# good

# %%
x+=5

x=10
x=x+5

# %%
print(bool(100))
print(bool(0.9))
print(False)
# Out:
# True
# True
# False
