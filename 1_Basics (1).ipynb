# %% [markdown]
# SINCHANA AB AMB2248

# %%
print(3/2)
# Out:
# 1.5

# %%
print(3//2)
# Out:
# 1

# %%
print(3%2)  #modulus operator - returns the remainder
# Out:
# 1

# %%
subject="AIML"   # string datatype - group of characters
print(subject)
# Out:
# AIML

# %%
subject='AIML'   # string datatype - group of characters
print(subject)
# Out:
# AIML

# %%
x=10
y=20
z=x+y
print(z)
# Out:
# 30

# %%
str1="GKVK"
str2="Agriculture"
str3=str1+" class for "+str2+" students"

print(str3)
#   + addition operator works as concatenation operator for strings datatype
# Out:
# GKVK class for Agriculture students

# %%
str="GKVK"
print(str*3)
# Out:
# GKVKGKVKGKVK

# %%
Datatypes

integer
float
string - character

# %%
Arithmetic operators
+  addition
-  subtraction
*  multiplication
/  float divisor
// floor divisor
%  modulus operator - returns the remainder

# %%
#multiple assigning operator
#a=10
#b=10
#c=10

a=b=c=10
print(a)
print(b)
print(c)
# Out:
# 10
# 10
# 10

# %%
9a=10
print(9a)
# Out:
#   Cell In[17], line 1
#     9a=10
#     ^
# SyntaxError: invalid decimal literal

# %%
num$1=10
print(num$1)
# Out:
#   Cell In[24], line 1
#     num$1=10
#        ^
# SyntaxError: invalid syntax

# %%
a=10
b=20
if a>b:
    print("a is greater than b")
else:
    print("b is greater than a")
# Out:
# a is greater than b

# %%
num=0
if num==0:
    print("num is zero")
elif(num<0):
    print("num is negative")
else:
    print("num is positive")
# Out:
# num is zero

# %%
if(10>5 and 10>3):
    print("hi")
# Out:
# hi

# %%
if(10>5 and 10<3):
    print("hi")

# %%
m=6
if(m>=9):
    print("A grade")
elif(m>=7 and m<9):
    print("B grade")
elif(m>=5 and m<7):
    print("C grade")
else:
    print("fail")
# Out:
# C grade

# %%
a=10
print(a)
print(type(a))
# Out:
# 10
# <class 'int'>

# %%
a=float(input("enter a number"))
print(a)
print(type(a))
# Out:
# 10.5
# <class 'float'>

# %%
a=[10,20,30]
print(type(a))
print(a)
# Out:
# <class 'list'>
# [10, 20, 30]

# %%
a=(10,20,30)
print(type(a))
print(a)
# Out:
# <class 'tuple'>
# (10, 20, 30)

# %%
a=10
b=20
print("value of a and b are",a,b)
# Out:
# value of a and b are 10 20

# %%
a=10
b=20
print("value of a and b are {} and {}".format(a,b))
print("value of a and b are {0} and {1}".format(a,b))
print("value of b and a are {1} and {0}".format(a,b))
# Out:
# value of a and b are 10 and 20
# value of a and b are 10 and 20
# value of b and a are 20 and 10

# %%
pi="pizza"
print("I love {2}, {0} and {1}".format("burger", pi, "icecream"))

# I love icecream, burger and pizza
# Out:
# I love icecream, burger and pizza

# %%
print("today is thrusday)
# Out:
#   Cell In[84], line 1
#     print("today is thrusday)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("Today is {3}.we are doing the course {1}. \
As part of this learning {2} with {0} "\
      .format("handson", "AI&ML", "python", "thrusday"))
# Out:
# Today is thrusday.we are doing the course AI&ML. As part of this learning python with handson

# %%
a=10
b=7
print("value of a and b are",a,b)

a=10
b=20
print("numbers are ",a,"and",b)
# Out:
# value of a and b are 10 7
# numbers are  10 and 20

# %%
a=10
print("value of a and b are {0} and {1}".format(a,b))
# Out:
# value of a and b are 10 and 7

# %%
city="bangalore"
name="ram"
age=22
print("my name is ",name,"and age is",age)
print("my name is {} and age is {}".format(name,age))
print("my name is {1} and age is {0}".format(age,name,city))
# Out:
# my name is  ram and age is 22
# my name is ram and age is 22
# my name is ram and age is 22

# %%
a=int(input("enter a number"))
print(a)
print(type(a))
# Out:
# 6
# <class 'int'>

# %%
a=int(input("enter a number"))
b=int(input("enter a number"))
c=a*b
print("product of {} and {} is {}.".format(a,b,c ))
# Out:
# product of 4 and 6 is 24.

# %%
a=input("enter your name")
b=int(input("enter your age"))
print("my name is{} and my age after 10 years will be{}".format(a,b+10))
# Out:
# my name isheramba and my age after 10 years will be44

# %%
day="tuesday"
if(day=="saturday"):
    print("colour dress")
else:
    print("uniform")
# Out:
# uniform

# %%
a=10
b=20
if(a>b):
    print("{} is greater than {}".format(a,b))
else:
    print("{} is not greater than {}".format(a,b))
# Out:
# 10 is not greater than 20

# %%
a=int(input("enter a number"))
b=int(input("enter a number"))
if(a>b):
    print("{} is greater between {} and {}".format(a,a,b))
elif(b>a):
     print("{} is greater between {} and {}".format(b,a,b))
else:
     print("{} and {} are equal".format(a,b))

# %%
#	Soil Quality Classification
ph = float(input("Enter soil pH value: "))

if ph < 5.5:
    print("Acidic soil")
elif ph <= 7.5:
    print("Neutral soil")
elif ph <= 8.5:
    print("Alkaline soil")
else:
    print("Highly alkaline soil")

# %%
# Out:
# mark absent for  12
# mark present for 11
# end
